# %% [markdown]
# # Feature Engineering
# ### **Mohon membaca setiap instruksi dan tag komentar dengan saksama sebelum melanjutkan pengerjaan.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# Scalling untuk MinMax Scaller
from sklearn.preprocessing import MinMaxScaler
# Set the maximum number of columns and rows to display to a large number
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # B. Outlier Handling

# %% [markdown]
# ### Outlier Handling : InterQuartile Handling

# %%
# untuk plot Q-Q
import scipy.stats as stats

# %%
df_california = pd.read_csv('california_dataset.csv')

# %%
from sklearn.model_selection import train_test_split
train_clfr, test_clfr = train_test_split(df_california, test_size= 0.2, random_state= 42)
# splitting terlebih dahulu
#NOTES :
#train : test = 80:20 atau 75:25 atau (minimum :70:30 atau maksimum: 90:10) bagi angka yg lain (85:15)
#data train di-handling outliernya
#tapi tidak untuk data test, karena data test ibarat representasi data masa depan yang digunakan untuk melihat performa Machine Learning

# %% [markdown]
# ### Assignment 1.a :
# 1. lakukan looping untuk melihat plot distribusi data dan outlier pada kolom-kolom : ['MedInc', 'HouseAge', 'AveRooms','AveBedrms', 'AveOccup'] di california_dataset.csv
# 2. Daftar nama kolom yang Anda cek, kolom_kolom = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def check_plot(df, variabel):
    plt.figure(figsize=(16, 4))
    plt.subplot(1, 3, 1)
    sns.histplot(df[variabel], bins=30)
    plt.title('histogram')

    plt.subplot(1, 3, 2)
    stats.probplot(df[variabel], dist="norm", plot=plt)
    plt.ylabel('variable quantiles')

    plt.subplot(1, 3, 3)
    sns.boxplot(y=df[variabel])
    plt.title('boxplot')

    plt.show()
# Assignment 1.a : lakukan looping untuk melihat plot distribusi data dan outlier pada kolom-kolom : ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup'] di california_dataset.csv
# Daftar nama kolom yang ingin Anda cek

# %%
kolom_kolom = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'AveOccup']

for kolom in kolom_kolom:
    print("Plot untuk:", kolom)
    check_plot(train_clfr, kolom)
# Out:
# Plot untuk: MedInc
# Plot untuk: HouseAge
# Plot untuk: AveRooms
# Plot untuk: AveBedrms
# Plot untuk: AveOccup

# %% [markdown]
# ### Assignment 1.b
# 1. Lakukan handling outlier pilih 1 kolom saja yang di handling dengan IQR setelah mengecek distribusinya
# 2. Dan cek distribusinya kembali

# %%
### Assignment 1.b Lakukan handling outlier pilih 1 kolom saja yang di handling dengan IQR setelah mengecek distribusinya
### Dan cek distribusinya kembali
def find_outlier_boundary(df, variable):

    # Mari kita hitung batas luar yang merupakan outlier

    IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)

    lower_boundary = df[variable].quantile(0.25) - (IQR * 1.5)
    upper_boundary = df[variable].quantile(0.75) + (IQR * 1.5)

    return upper_boundary, lower_boundary

# %%
# Melakukan loop untuk mengecek distribusi tiap kolom
Population_upper_limit, Population_lower_limit = find_outlier_boundary(train_clfr, 'AveOccup')
Population_upper_limit, Population_lower_limit
# Out:
# (np.float64(4.556801637852593), np.float64(1.1519972702456773))

# %%
import numpy as np

# %%
train_clfr['AveOccup'] = np.where(
    train_clfr['AveOccup'] > Population_upper_limit, Population_upper_limit,  # Jika lebih besar dari batas atas, ganti dengan batas atas
    np.where(
        train_clfr['AveOccup'] < Population_lower_limit, Population_lower_limit,  # Jika lebih kecil dari batas bawah, ganti dengan batas bawah
        train_clfr['AveOccup']  # Jika tidak outlier, biarkan tetap sama
    )
)

# %%
check_plot(train_clfr, 'AveOccup')

# %% [markdown]
# # C. Missing Value Handling
# Missing Value Merupakan nilai yang hilang di suatu kolom, namun tidak hanya sebatas itu. Untuk nilai yang tidak sesuai tapi muncul didalam suatu kolom tertentu juga bisa dianggap sebagai missing value. Misal tipenya kategorikal tapi isinya ada yang berupa angka dan juga sebaliknya.

# %%
df_company = pd.read_csv('company.csv')

# %%
df_company.head
# Out:
# <bound method NDFrame.head of                               Revenue                     Size  Rating  \
# 0            Unknown / Non-Applicable   1001 to 5000 employees     3.1
# 1              $1 to $2 billion (USD)  5001 to 10000 employees     4.2
# 2          $100 to $500 million (USD)   1001 to 5000 employees     3.8
# 3          $100 to $500 million (USD)    501 to 1000 employees     3.5
# 4            Unknown / Non-Applicable      51 to 200 employees     2.9
# 5            Unknown / Non-Applicable      51 to 200 employees     4.2
# 6                  $10+ billion (USD)         10000+ employees     3.9
# 7              $1 to $2 billion (USD)   1001 to 5000 employees     3.5
# 8              $2 to $5 billion (USD)  5001 to 10000 employees     4.4
# 9            Unknown / Non-Applicable      51 to 200 employees     3.6
# 10         $100 to $500 million (USD)    501 to 1000 employees     4.5
# 11           Unknown / Non-Applicable      51 to 200 employees     4.7
# 12   $500 million to $1 billion (USD)   1001 to 5000 employees     3.7
# 13             $1 to $2 billion (USD)     201 to 500 employees     3.1
# 14         $100 to $500 million (USD)   1001 to 5000 employees     3.4
# 15           Unknown / Non-Applicable        1 to 50 employees     4.4
# 16           Unknown / Non-Applicable      51 to 200 employees     4.1
# 17   $500 million to $1 billion (USD)   1001 to 5000 employees     3.5
# 18            $5 to $10 billion (USD)  5001 to 10000 employees     4.2
# 19           Unknown / Non-Applicable  5001 to 10000 employees     3.5
# 20           Unknown / Non-Applicable      51 to 200 employees     3.2
# 21         $100 to $500 million (USD)      51 to 200 employees     4.3
# 22         $100 to $500 million (USD)   1001 to 5000 employees     3.5
# 23            $5 to $10 billion (USD)  5001 to 10000 employees     3.5
# 24           $10 to $25 million (USD)      51 to 200 employees     3.4
# 25           $25 to $50 million (USD)      51 to 200 employees     4.7
# 26         $100 to $500 million (USD)      51 to 200 employees     4.2
# 27           Unknown / Non-Applicable   1001 to 5000 employees     3.8
# 28           $25 to $50 million (USD)      51 to 200 employees     4.5
# 29           Unknown / Non-Applicable      51 to 200 employees     2.8
# 30         $100 to $500 million (USD)   1001 to 5000 employees     3.8
# 31                 $10+ billion (USD)         10000+ employees     3.9
# 32           Unknown / Non-Applicable        1 to 50 employees     5.0
# 33             $1 to $2 billion (USD)   1001 to 5000 employees     4.8
# 34          $50 to $100 million (USD)     201 to 500 employees     3.6
# 35             $2 to $5 billion (USD)   1001 to 5000 employees     3.3
# 36          $50 to $100 million (USD)   1001 to 5000 employees     2.7
# 37           Unknown / Non-Applicable    501 to 1000 employees     2.7
# 38             $1 to $5 million (USD)        1 to 50 employees     2.2
# 39         $100 to $500 million (USD)    501 to 1000 employees     3.4
# 40         $100 to $500 million (USD)    501 to 1000 employees     3.1
# 41                 $10+ billion (USD)         10000+ employees     3.4
# 42         $100 to $500 million (USD)   1001 to 5000 employees     2.6
# 43           Unknown / Non-Applicable      51 to 200 employees     5.0
# 44           $10 to $25 million (USD)      51 to 200 employees     4.2
# 45                 $10+ billion (USD)         10000+ employees     4.1
# 46           Unknown / Non-Applicable     201 to 500 employees     4.8
# 47           Unknown / Non-Applicable    501 to 1000 employees     3.3
# 48           Unknown / Non-Applicable   1001 to 5000 employees     3.7
# 49           Unknown / Non-Applicable     201 to 500 employees     4.3
# 50           $10 to $25 million (USD)        1 to 50 employees     4.8
# 51                 $10+ billion (USD)         10000+ employees     3.7
# 52           Unknown / Non-Applicable    501 to 1000 employees     4.0
# 53           $10 to $25 million (USD)      51 to 200 employees     4.8
# 54           Unknown / Non-Applicable      51 to 200 employees     3.5
# 55         $100 to $500 million (USD)  5001 to 10000 employees     3.7
# 56             $1 to $5 million (USD)     201 to 500 employees     3.5
# 57             $2 to $5 billion (USD)   1001 to 5000 employees     4.1
# 58           Unknown / Non-Applicable   1001 to 5000 employees     3.2
# 59           $25 to $50 million (USD)     201 to 500 employees     4.5
# 60                 $10+ billion (USD)         10000+ employees     3.8
# 61         $100 to $500 million (USD)     201 to 500 employees     4.5
# 62             $1 to $2 billion (USD)   1001 to 5000 employees     3.5
# 63           Unknown / Non-Applicable      51 to 200 employees     4.2
# 64         $100 to $500 million (USD)     201 to 500 employees     3.8
# 65         $100 to $500 million (USD)   1001 to 5000 employees     3.7
# 66           Unknown / Non-Applicable    501 to 1000 employees     3.7
# 67          $50 to $100 million (USD)   1001 to 5000 employees     4.0
# 68           Unknown / Non-Applicable    501 to 1000 employees     3.3
# 69           Unknown / Non-Applicable        1 to 50 employees     2.5
# 70           $25 to $50 million (USD)      51 to 200 employees     4.2
# 71           Unknown / Non-Applicable    501 to 1000 employees     3.3
# 72             $2 to $5 billion (USD)  5001 to 10000 employees     4.0
# 73                 $10+ billion (USD)         10000+ employees     3.7
# 74           Unknown / Non-Applicable     201 to 500 employees     4.9
# 75         $100 to $500 million (USD)   1001 to 5000 employees     3.4
# 76           Unknown / Non-Applicable   1001 to 5000 employees     3.1
# 77           Unknown / Non-Applicable   1001 to 5000 employees     3.5
# 78           Unknown / Non-Applicable     201 to 500 employees     2.9
# 79         $100 to $500 million (USD)     201 to 500 employees     3.3
# 80                 $10+ billion (USD)         10000+ employees     4.0
# 81           $25 to $50 million (USD)      51 to 200 employees     3.6
# 82           $25 to $50 million (USD)      51 to 200 employees     4.7
# 83           Unknown / Non-Applicable        1 to 50 employees     4.9
# 84           $25 to $50 million (USD)      51 to 200 employees     4.3
# 85           Unknown / Non-Applicable   1001 to 5000 employees     4.0
# 86           Unknown / Non-Applicable    501 to 1000 employees     2.6
# 87           $10 to $25 million (USD)      51 to 200 employees     4.5
# 88           Unknown / Non-Applicable     201 to 500 employees     4.8
# 89                 $10+ billion (USD)         10000+ employees     3.9
# 90                 $10+ billion (USD)         10000+ employees     4.0
# 91            $5 to $10 million (USD)      51 to 200 employees     4.4
# 92             $1 to $2 billion (USD)  5001 to 10000 employees     4.2
# 93           Unknown / Non-Applicable     201 to 500 employees     3.6
# 94         $100 to $500 million (USD)   1001 to 5000 employees     3.4
# 95             $2 to $5 billion (USD)  5001 to 10000 employees     4.4
# 96           $10 to $25 million (USD)      51 to 200 employees     3.5
# 97                 $10+ billion (USD)         10000+ employees     3.9
# 98           $10 to $25 million (USD)      51 to 200 employees     3.8
# 99                 $10+ billion (USD)   1001 to 5000 employees     3.5
# 100        Less than $1 million (USD)        1 to 50 employees     4.9
# 101          Unknown / Non-Applicable        1 to 50 employees     4.4
# 102          Unknown / Non-Applicable      51 to 200 employees     4.1
# 103            $2 to $5 billion (USD)  5001 to 10000 employees     4.0
# 104            $2 to $5 billion (USD)  5001 to 10000 employees     4.4
# 105         $50 to $100 million (USD)    501 to 1000 employees     3.8
# 106          Unknown / Non-Applicable    501 to 1000 employees     3.2
# 107          $10 to $25 million (USD)      51 to 200 employees     2.9
# 108          Unknown / Non-Applicable         10000+ employees     4.1
# 109           $5 to $10 million (USD)         10000+ employees     3.7
# 110            $2 to $5 billion (USD)   1001 to 5000 employees     3.2
# 111          Unknown / Non-Applicable      51 to 200 employees     4.9
# 112            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 113          Unknown / Non-Applicable        1 to 50 employees     5.0
# 114        $100 to $500 million (USD)   1001 to 5000 employees     4.0
# 115          Unknown / Non-Applicable        1 to 50 employees     3.6
# 116           $5 to $10 million (USD)      51 to 200 employees     4.0
# 117            $2 to $5 billion (USD)   1001 to 5000 employees     3.2
# 118          Unknown / Non-Applicable      51 to 200 employees     5.0
# 119         $50 to $100 million (USD)     201 to 500 employees     4.8
# 120          Unknown / Non-Applicable      51 to 200 employees     4.5
# 121          Unknown / Non-Applicable      51 to 200 employees     4.7
# 122        $100 to $500 million (USD)    501 to 1000 employees     4.5
# 123          $25 to $50 million (USD)      51 to 200 employees     4.2
# 124          Unknown / Non-Applicable      51 to 200 employees     3.4
# 125            $2 to $5 billion (USD)  5001 to 10000 employees     3.8
# 126          Unknown / Non-Applicable      51 to 200 employees     4.7
# 127          Unknown / Non-Applicable      51 to 200 employees     3.6
# 128          $25 to $50 million (USD)      51 to 200 employees     4.2
# 129            $2 to $5 billion (USD)  5001 to 10000 employees     3.8
# 130          Unknown / Non-Applicable        1 to 50 employees     5.0
# 131         $50 to $100 million (USD)     201 to 500 employees     4.9
# 132          $25 to $50 million (USD)      51 to 200 employees     4.4
# 133        $100 to $500 million (USD)   1001 to 5000 employees     3.3
# 134          Unknown / Non-Applicable      51 to 200 employees     3.2
# 135          Unknown / Non-Applicable      51 to 200 employees     3.2
# 136         $50 to $100 million (USD)     201 to 500 employees     4.9
# 137          Unknown / Non-Applicable     201 to 500 employees     4.2
# 138          $25 to $50 million (USD)     201 to 500 employees     4.5
# 139          Unknown / Non-Applicable     201 to 500 employees     4.8
# 140          Unknown / Non-Applicable    501 to 1000 employees     3.8
# 141          Unknown / Non-Applicable   1001 to 5000 employees     3.7
# 142           $5 to $10 million (USD)      51 to 200 employees     3.3
# 143            $1 to $2 billion (USD)  5001 to 10000 employees     3.3
# 144          $10 to $25 million (USD)        1 to 50 employees     5.0
# 145        $100 to $500 million (USD)    501 to 1000 employees     3.8
# 146          $10 to $25 million (USD)   1001 to 5000 employees     3.4
# 147         $50 to $100 million (USD)    501 to 1000 employees     2.4
# 148          $10 to $25 million (USD)      51 to 200 employees     2.9
# 149          Unknown / Non-Applicable     201 to 500 employees     4.4
# 150                $10+ billion (USD)         10000+ employees     2.9
# 151         $50 to $100 million (USD)     201 to 500 employees     2.7
# 152          Unknown / Non-Applicable   1001 to 5000 employees     4.2
# 153        $100 to $500 million (USD)     201 to 500 employees     3.5
# 154                                -1                       -1    -1.0
# 155            $2 to $5 billion (USD)         10000+ employees     4.2
# 156        $100 to $500 million (USD)    501 to 1000 employees     4.5
# 157          Unknown / Non-Applicable        1 to 50 employees     4.4
# 158                                -1                       -1    -1.0
# 159                $10+ billion (USD)         10000+ employees     3.5
# 160        $100 to $500 million (USD)     201 to 500 employees     4.5
# 161            $1 to $2 billion (USD)   1001 to 5000 employees     4.1
# 162            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 163          $25 to $50 million (USD)    501 to 1000 employees     2.7
# 164                $10+ billion (USD)         10000+ employees     3.4
# 165          Unknown / Non-Applicable     201 to 500 employees     4.4
# 166            $2 to $5 billion (USD)  5001 to 10000 employees     4.0
# 167            $1 to $2 billion (USD)  5001 to 10000 employees     4.2
# 168                $10+ billion (USD)         10000+ employees     3.5
# 169        $100 to $500 million (USD)   1001 to 5000 employees     2.3
# 170           $5 to $10 billion (USD)  5001 to 10000 employees     3.4
# 171          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 172        $100 to $500 million (USD)     201 to 500 employees     4.7
# 173          Unknown / Non-Applicable     201 to 500 employees     3.9
# 174            $1 to $2 billion (USD)   1001 to 5000 employees     3.3
# 175          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 176         $50 to $100 million (USD)     201 to 500 employees     4.4
# 177  $500 million to $1 billion (USD)   1001 to 5000 employees     3.7
# 178  $500 million to $1 billion (USD)   1001 to 5000 employees     3.5
# 179         $50 to $100 million (USD)    501 to 1000 employees     3.6
# 180        $100 to $500 million (USD)    501 to 1000 employees     3.8
# 181          $25 to $50 million (USD)     201 to 500 employees     4.7
# 182            $1 to $2 billion (USD)   1001 to 5000 employees     3.5
# 183  $500 million to $1 billion (USD)  5001 to 10000 employees     3.3
# 184          Unknown / Non-Applicable      51 to 200 employees     3.9
# 185                $10+ billion (USD)  5001 to 10000 employees     3.7
# 186        $100 to $500 million (USD)    501 to 1000 employees     3.9
# 187                $10+ billion (USD)         10000+ employees     4.0
# 188         $50 to $100 million (USD)     201 to 500 employees     4.2
# 189          Unknown / Non-Applicable                  Unknown     3.6
# 190          Unknown / Non-Applicable    501 to 1000 employees     4.7
# 191          Unknown / Non-Applicable      51 to 200 employees     4.1
# 192                $10+ billion (USD)         10000+ employees     4.0
# 193          Unknown / Non-Applicable                  Unknown     5.0
# 194                $10+ billion (USD)         10000+ employees     4.0
# 195          Unknown / Non-Applicable      51 to 200 employees     4.3
# 196        $100 to $500 million (USD)  5001 to 10000 employees     3.8
# 197        $100 to $500 million (USD)     201 to 500 employees     3.8
# 198        $100 to $500 million (USD)    501 to 1000 employees     4.6
# 199          Unknown / Non-Applicable      51 to 200 employees     4.1
# 200          $10 to $25 million (USD)      51 to 200 employees     3.4
# 201          $10 to $25 million (USD)      51 to 200 employees     4.1
# 202        $100 to $500 million (USD)    501 to 1000 employees     3.7
# 203         $50 to $100 million (USD)      51 to 200 employees     4.4
# 204                $10+ billion (USD)         10000+ employees     3.9
# 205            $1 to $2 billion (USD)   1001 to 5000 employees     3.6
# 206        $100 to $500 million (USD)    501 to 1000 employees     4.5
# 207        $100 to $500 million (USD)   1001 to 5000 employees     3.7
# 208         $50 to $100 million (USD)     201 to 500 employees     2.9
# 209            $1 to $5 million (USD)        1 to 50 employees     5.0
# 210        $100 to $500 million (USD)     201 to 500 employees     3.4
# 211            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 212            $1 to $5 million (USD)        1 to 50 employees     5.0
# 213          Unknown / Non-Applicable     201 to 500 employees     4.8
# 214  $500 million to $1 billion (USD)   1001 to 5000 employees     3.9
# 215                $10+ billion (USD)         10000+ employees     4.0
# 216        $100 to $500 million (USD)    501 to 1000 employees     4.3
# 217  $500 million to $1 billion (USD)    501 to 1000 employees     3.5
# 218                $10+ billion (USD)  5001 to 10000 employees     3.7
# 219          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 220          Unknown / Non-Applicable   1001 to 5000 employees     3.1
# 221        $100 to $500 million (USD)      51 to 200 employees     4.3
# 222        $100 to $500 million (USD)      51 to 200 employees     4.2
# 223         $50 to $100 million (USD)     201 to 500 employees     4.4
# 224            $2 to $5 billion (USD)    501 to 1000 employees     3.6
# 225           $5 to $10 million (USD)      51 to 200 employees     4.5
# 226        $100 to $500 million (USD)   1001 to 5000 employees     3.0
# 227          Unknown / Non-Applicable      51 to 200 employees     5.0
# 228         $50 to $100 million (USD)    501 to 1000 employees     3.6
# 229            $2 to $5 billion (USD)  5001 to 10000 employees     3.6
# 230           $5 to $10 million (USD)        1 to 50 employees    -1.0
# 231        $100 to $500 million (USD)    501 to 1000 employees     3.8
# 232  $500 million to $1 billion (USD)  5001 to 10000 employees     3.3
# 233          Unknown / Non-Applicable   1001 to 5000 employees     3.8
# 234            $1 to $2 billion (USD)   1001 to 5000 employees     3.5
# 235            $1 to $2 billion (USD)         10000+ employees     3.3
# 236        Less than $1 million (USD)        1 to 50 employees     4.6
# 237                $10+ billion (USD)         10000+ employees     3.8
# 238          Unknown / Non-Applicable      51 to 200 employees     3.9
# 239          Unknown / Non-Applicable        1 to 50 employees     3.9
# 240          $25 to $50 million (USD)      51 to 200 employees     4.7
# 241            $1 to $2 billion (USD)   1001 to 5000 employees     4.8
# 242         $50 to $100 million (USD)     201 to 500 employees     3.1
# 243          $10 to $25 million (USD)     201 to 500 employees     3.6
# 244          Unknown / Non-Applicable        1 to 50 employees     5.0
# 245                $10+ billion (USD)         10000+ employees     3.7
# 246                $10+ billion (USD)         10000+ employees     3.7
# 247          $10 to $25 million (USD)      51 to 200 employees     3.9
# 248        Less than $1 million (USD)        1 to 50 employees     4.3
# 249         $50 to $100 million (USD)     201 to 500 employees     4.2
# 250                $10+ billion (USD)  5001 to 10000 employees     3.7
# 251          Unknown / Non-Applicable        1 to 50 employees     4.0
# 252                $10+ billion (USD)         10000+ employees     3.3
# 253          Unknown / Non-Applicable   1001 to 5000 employees     4.1
# 254         $50 to $100 million (USD)     201 to 500 employees     3.3
# 255          Unknown / Non-Applicable     201 to 500 employees     3.9
# 256           $5 to $10 billion (USD)         10000+ employees     3.1
# 257         $50 to $100 million (USD)     201 to 500 employees     4.2
# 258          Unknown / Non-Applicable                  Unknown     5.0
# 259          Unknown / Non-Applicable      51 to 200 employees     2.9
# 260          Unknown / Non-Applicable    501 to 1000 employees     4.7
# 261          Unknown / Non-Applicable                  Unknown     3.6
# 262          Unknown / Non-Applicable   1001 to 5000 employees     3.8
# 263            $2 to $5 billion (USD)   1001 to 5000 employees     3.3
# 264  $500 million to $1 billion (USD)   1001 to 5000 employees     3.7
# 265        $100 to $500 million (USD)   1001 to 5000 employees     3.8
# 266        $100 to $500 million (USD)   1001 to 5000 employees     3.2
# 267          $10 to $25 million (USD)     201 to 500 employees     4.6
# 268                $10+ billion (USD)         10000+ employees     3.5
# 269          Unknown / Non-Applicable        1 to 50 employees     5.0
# 270          Unknown / Non-Applicable      51 to 200 employees     4.1
# 271        $100 to $500 million (USD)   1001 to 5000 employees     4.1
# 272                $10+ billion (USD)         10000+ employees     3.5
# 273          $10 to $25 million (USD)      51 to 200 employees     3.2
# 274          Unknown / Non-Applicable                  Unknown     5.0
# 275            $1 to $2 billion (USD)   1001 to 5000 employees     4.7
# 276            $1 to $2 billion (USD)     201 to 500 employees     3.8
# 277                $10+ billion (USD)         10000+ employees     3.6
# 278          Unknown / Non-Applicable     201 to 500 employees     4.8
# 279            $2 to $5 billion (USD)         10000+ employees     3.3
# 280        $100 to $500 million (USD)   1001 to 5000 employees     3.7
# 281          $25 to $50 million (USD)      51 to 200 employees     5.0
# 282          Unknown / Non-Applicable                  Unknown    -1.0
# 283        $100 to $500 million (USD)    501 to 1000 employees     3.4
# 284          Unknown / Non-Applicable        1 to 50 employees     5.0
# 285          Unknown / Non-Applicable                  Unknown    -1.0
# 286                $10+ billion (USD)         10000+ employees     4.0
# 287           $5 to $10 billion (USD)         10000+ employees     4.2
# 288          Unknown / Non-Applicable      51 to 200 employees     4.3
# 289          $10 to $25 million (USD)      51 to 200 employees     3.4
# 290          Unknown / Non-Applicable      51 to 200 employees    -1.0
# 291           $5 to $10 million (USD)     201 to 500 employees     4.4
# 292                $10+ billion (USD)         10000+ employees     3.5
# 293            $1 to $2 billion (USD)   1001 to 5000 employees     3.7
# 294        $100 to $500 million (USD)    501 to 1000 employees     3.7
# 295          Unknown / Non-Applicable         10000+ employees     4.1
# 296          Unknown / Non-Applicable        1 to 50 employees     3.4
# 297          Unknown / Non-Applicable        1 to 50 employees     4.5
# 298          Unknown / Non-Applicable   1001 to 5000 employees     3.5
# 299                $10+ billion (USD)         10000+ employees     3.6
# 300                $10+ billion (USD)         10000+ employees     3.2
# 301          $25 to $50 million (USD)    501 to 1000 employees     3.7
# 302        $100 to $500 million (USD)    501 to 1000 employees     4.0
# 303          Unknown / Non-Applicable      51 to 200 employees     3.2
# 304          $25 to $50 million (USD)      51 to 200 employees     4.5
# 305          Unknown / Non-Applicable      51 to 200 employees     3.4
# 306          $10 to $25 million (USD)     201 to 500 employees     3.9
# 307            $1 to $5 million (USD)        1 to 50 employees     3.2
# 308          Unknown / Non-Applicable                  Unknown     5.0
# 309  $500 million to $1 billion (USD)  5001 to 10000 employees     3.4
# 310          Unknown / Non-Applicable      51 to 200 employees     4.4
# 311        $100 to $500 million (USD)  5001 to 10000 employees     3.8
# 312        $100 to $500 million (USD)     201 to 500 employees     3.8
# 313        $100 to $500 million (USD)     201 to 500 employees     3.5
# 314          Unknown / Non-Applicable     201 to 500 employees     3.8
# 315            $2 to $5 billion (USD)   1001 to 5000 employees     3.9
# 316            $1 to $5 million (USD)      51 to 200 employees     3.4
# 317          $25 to $50 million (USD)      51 to 200 employees     3.8
# 318        $100 to $500 million (USD)    501 to 1000 employees     4.6
# 319            $1 to $5 million (USD)        1 to 50 employees    -1.0
# 320           $5 to $10 million (USD)      51 to 200 employees     4.6
# 321                $10+ billion (USD)         10000+ employees     3.9
# 322          Unknown / Non-Applicable        1 to 50 employees    -1.0
# 323          Unknown / Non-Applicable   1001 to 5000 employees     3.7
# 324          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 325         $50 to $100 million (USD)      51 to 200 employees     4.4
# 326          $25 to $50 million (USD)   1001 to 5000 employees     3.7
# 327          $25 to $50 million (USD)     201 to 500 employees     3.3
# 328           $5 to $10 million (USD)      51 to 200 employees     3.4
# 329          Unknown / Non-Applicable      51 to 200 employees    -1.0
# 330        $100 to $500 million (USD)    501 to 1000 employees     3.7
# 331           $5 to $10 billion (USD)   1001 to 5000 employees     3.7
# 332          Unknown / Non-Applicable    501 to 1000 employees     4.8
# 333          $10 to $25 million (USD)        1 to 50 employees     5.0
# 334                $10+ billion (USD)         10000+ employees     3.9
# 335          Unknown / Non-Applicable    501 to 1000 employees     3.4
# 336            $1 to $2 billion (USD)         10000+ employees     3.3
# 337        $100 to $500 million (USD)    501 to 1000 employees     4.6
# 338        Less than $1 million (USD)        1 to 50 employees    -1.0
# 339          Unknown / Non-Applicable    501 to 1000 employees     2.6
# 340        $100 to $500 million (USD)     201 to 500 employees     3.8
# 341          Unknown / Non-Applicable        1 to 50 employees     4.8
# 342          Unknown / Non-Applicable      51 to 200 employees     3.9
# 343          Unknown / Non-Applicable    501 to 1000 employees     4.0
# 344          $10 to $25 million (USD)      51 to 200 employees     4.2
# 345        $100 to $500 million (USD)   1001 to 5000 employees     3.7
# 346            $2 to $5 billion (USD)   1001 to 5000 employees     3.0
# 347                $10+ billion (USD)         10000+ employees     3.5
# 348            $1 to $5 million (USD)        1 to 50 employees     2.9
# 349          Unknown / Non-Applicable        1 to 50 employees     5.0
# 350        $100 to $500 million (USD)     201 to 500 employees     4.7
# 351                                -1                       -1    -1.0
# 352            $1 to $2 billion (USD)  5001 to 10000 employees     4.5
# 353          Unknown / Non-Applicable        1 to 50 employees     4.9
# 354          Unknown / Non-Applicable      51 to 200 employees     4.6
# 355            $1 to $5 million (USD)        1 to 50 employees     5.0
# 356            $1 to $5 million (USD)      51 to 200 employees     3.9
# 357                                -1                       -1    -1.0
# 358                                -1                       -1    -1.0
# 359                                -1                       -1    -1.0
# 360                                -1                       -1    -1.0
# 361                                -1                       -1    -1.0
# 362                                -1                       -1    -1.0
# 363            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 364          Unknown / Non-Applicable     201 to 500 employees     4.3
# 365                $10+ billion (USD)         10000+ employees     3.7
# 366            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 367  $500 million to $1 billion (USD)   1001 to 5000 employees     3.9
# 368          Unknown / Non-Applicable      51 to 200 employees     4.7
# 369          Unknown / Non-Applicable     201 to 500 employees     4.8
# 370                $10+ billion (USD)         10000+ employees     4.0
# 371          Unknown / Non-Applicable      51 to 200 employees     4.4
# 372          Unknown / Non-Applicable         10000+ employees     3.2
# 373          Unknown / Non-Applicable        1 to 50 employees     4.5
# 374        $100 to $500 million (USD)     201 to 500 employees     3.5
# 375        $100 to $500 million (USD)   1001 to 5000 employees     4.4
# 376            $1 to $5 million (USD)        1 to 50 employees     3.1
# 377          Unknown / Non-Applicable     201 to 500 employees     3.5
# 378         $50 to $100 million (USD)   1001 to 5000 employees     3.8
# 379          Unknown / Non-Applicable  5001 to 10000 employees     3.7
# 380  $500 million to $1 billion (USD)    501 to 1000 employees     3.5
# 381                $10+ billion (USD)  5001 to 10000 employees     3.7
# 382          Unknown / Non-Applicable        1 to 50 employees     5.0
# 383                $10+ billion (USD)         10000+ employees     4.0
# 384          Unknown / Non-Applicable   1001 to 5000 employees     3.6
# 385          Unknown / Non-Applicable     201 to 500 employees     4.8
# 386          $10 to $25 million (USD)      51 to 200 employees     3.8
# 387                $10+ billion (USD)  5001 to 10000 employees     3.6
# 388                                -1                       -1    -1.0
# 389                                -1                       -1    -1.0
# 390          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 391            $1 to $2 billion (USD)  5001 to 10000 employees     4.1
# 392        $100 to $500 million (USD)   1001 to 5000 employees     3.6
# 393          $25 to $50 million (USD)      51 to 200 employees     4.5
# 394          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 395                $10+ billion (USD)         10000+ employees     3.4
# 396        $100 to $500 million (USD)    501 to 1000 employees     4.3
# 397            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 398        $100 to $500 million (USD)   1001 to 5000 employees     4.0
# 399        $100 to $500 million (USD)     201 to 500 employees     4.5
# 400        $100 to $500 million (USD)    501 to 1000 employees     4.5
# 401          Unknown / Non-Applicable         10000+ employees     3.9
# 402        $100 to $500 million (USD)   1001 to 5000 employees     4.0
# 403  $500 million to $1 billion (USD)     201 to 500 employees     3.6
# 404                $10+ billion (USD)  5001 to 10000 employees     3.3
# 405          Unknown / Non-Applicable      51 to 200 employees     5.0
# 406            $2 to $5 billion (USD)   1001 to 5000 employees     4.1
# 407          Unknown / Non-Applicable   1001 to 5000 employees     3.2
# 408          $10 to $25 million (USD)      51 to 200 employees     4.9
# 409          Unknown / Non-Applicable                  Unknown    -1.0
# 410          Unknown / Non-Applicable     201 to 500 employees     3.3
# 411          Unknown / Non-Applicable        1 to 50 employees    -1.0
# 412          Unknown / Non-Applicable        1 to 50 employees     5.0
# 413            $1 to $5 million (USD)        1 to 50 employees     3.4
# 414            $1 to $5 million (USD)        1 to 50 employees     4.1
# 415          $10 to $25 million (USD)      51 to 200 employees     5.0
# 416        $100 to $500 million (USD)     201 to 500 employees     4.2
# 417           $5 to $10 billion (USD)         10000+ employees     3.7
# 418            $1 to $2 billion (USD)  5001 to 10000 employees     3.8
# 419            $1 to $5 million (USD)     201 to 500 employees     4.8
# 420            $2 to $5 billion (USD)         10000+ employees     3.5
# 421        $100 to $500 million (USD)    501 to 1000 employees     4.6
# 422        Less than $1 million (USD)        1 to 50 employees     4.5
# 423            $2 to $5 billion (USD)   1001 to 5000 employees     3.9
# 424          Unknown / Non-Applicable                  Unknown     3.4
# 425            $1 to $5 million (USD)        1 to 50 employees    -1.0
# 426          $10 to $25 million (USD)      51 to 200 employees     4.1
# 427          Unknown / Non-Applicable    501 to 1000 employees     3.7
# 428            $1 to $5 million (USD)     201 to 500 employees     3.5
# 429           $5 to $10 million (USD)      51 to 200 employees     4.6
# 430          Unknown / Non-Applicable                  Unknown    -1.0
# 431          Unknown / Non-Applicable        1 to 50 employees    -1.0
# 432         $50 to $100 million (USD)      51 to 200 employees     4.4
# 433          Unknown / Non-Applicable      51 to 200 employees     3.6
# 434            $2 to $5 billion (USD)         10000+ employees     3.1
# 435            $1 to $5 million (USD)        1 to 50 employees     5.0
# 436          Unknown / Non-Applicable        1 to 50 employees     5.0
# 437          Unknown / Non-Applicable      51 to 200 employees    -1.0
# 438          Unknown / Non-Applicable        1 to 50 employees    -1.0
# 439          Unknown / Non-Applicable     201 to 500 employees     3.5
# 440        Less than $1 million (USD)        1 to 50 employees    -1.0
# 441          Unknown / Non-Applicable        1 to 50 employees     5.0
# 442          Unknown / Non-Applicable         10000+ employees     2.7
# 443        $100 to $500 million (USD)   1001 to 5000 employees     4.1
# 444          Unknown / Non-Applicable                  Unknown     2.1
# 445          Unknown / Non-Applicable    501 to 1000 employees     4.8
# 446          $25 to $50 million (USD)     201 to 500 employees     4.5
# 447            $2 to $5 billion (USD)  5001 to 10000 employees     4.0
# 448           $5 to $10 billion (USD)         10000+ employees     3.3
# 449                $10+ billion (USD)         10000+ employees     3.9
# 450        $100 to $500 million (USD)   1001 to 5000 employees     3.2
# 451          Unknown / Non-Applicable   1001 to 5000 employees     3.2
# 452                $10+ billion (USD)         10000+ employees     3.7
# 453          $25 to $50 million (USD)      51 to 200 employees     4.4
# 454            $1 to $5 million (USD)        1 to 50 employees     3.1
# 455            $1 to $2 billion (USD)         10000+ employees     3.3
# 456         $50 to $100 million (USD)    501 to 1000 employees     3.5
# 457        Less than $1 million (USD)        1 to 50 employees    -1.0
# 458          Unknown / Non-Applicable    501 to 1000 employees     2.6
# 459                                -1                       -1    -1.0
# 460        $100 to $500 million (USD)   1001 to 5000 employees     2.7
# 461          Unknown / Non-Applicable    501 to 1000 employees     3.5
# 462           $5 to $10 million (USD)        1 to 50 employees     3.2
# 463        $100 to $500 million (USD)     201 to 500 employees     3.8
# 464        Less than $1 million (USD)      51 to 200 employees     4.2
# 465          Unknown / Non-Applicable        1 to 50 employees     4.8
# 466          $10 to $25 million (USD)      51 to 200 employees     4.2
# 467          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 468         $50 to $100 million (USD)   1001 to 5000 employees     4.0
# 469          Unknown / Non-Applicable      51 to 200 employees     3.9
# 470        $100 to $500 million (USD)   1001 to 5000 employees     3.7
# 471         $50 to $100 million (USD)    501 to 1000 employees     3.9
# 472                $10+ billion (USD)         10000+ employees     3.5
# 473          Unknown / Non-Applicable        1 to 50 employees     4.0
# 474            $2 to $5 billion (USD)   1001 to 5000 employees     3.0
# 475            $2 to $5 billion (USD)  5001 to 10000 employees     3.7
# 476        Less than $1 million (USD)        1 to 50 employees     4.5
# 477          $25 to $50 million (USD)      51 to 200 employees     2.8
# 478          $10 to $25 million (USD)     201 to 500 employees     4.1
# 479         $50 to $100 million (USD)     201 to 500 employees     2.9
# 480        $100 to $500 million (USD)     201 to 500 employees     4.7
# 481        $100 to $500 million (USD)   1001 to 5000 employees     3.4
# 482            $2 to $5 billion (USD)   1001 to 5000 employees     3.9
# 483        $100 to $500 million (USD)     201 to 500 employees     2.9
# 484            $1 to $2 billion (USD)  5001 to 10000 employees     4.5
# 485          Unknown / Non-Applicable        1 to 50 employees     4.9
# 486            $1 to $5 million (USD)        1 to 50 employees     5.0
# 487          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 488          Unknown / Non-Applicable   1001 to 5000 employees     3.5
# 489            $1 to $5 million (USD)        1 to 50 employees     3.5
# 490        Less than $1 million (USD)        1 to 50 employees     4.0
# 491            $1 to $5 million (USD)      51 to 200 employees     3.9
# 492        $100 to $500 million (USD)     201 to 500 employees     3.4
# 493                $10+ billion (USD)         10000+ employees     3.5
# 494            $1 to $5 million (USD)        1 to 50 employees     4.7
# 495                                -1                       -1    -1.0
# 496                                -1                       -1    -1.0
# 497                                -1                       -1    -1.0
# 498                                -1                       -1    -1.0
# 499                                -1                       -1    -1.0
# 500                                -1                       -1    -1.0
# 501          $10 to $25 million (USD)        1 to 50 employees     4.6
# 502          $10 to $25 million (USD)      51 to 200 employees     4.0
# 503            $1 to $5 million (USD)        1 to 50 employees     4.0
# 504          Unknown / Non-Applicable        1 to 50 employees    -1.0
# 505          $10 to $25 million (USD)      51 to 200 employees     4.7
# 506          $25 to $50 million (USD)      51 to 200 employees     3.5
# 507            $1 to $5 million (USD)        1 to 50 employees     5.0
# 508                $10+ billion (USD)         10000+ employees     4.1
# 509                $10+ billion (USD)         10000+ employees     4.0
# 510          Unknown / Non-Applicable     201 to 500 employees     3.6
# 511          Unknown / Non-Applicable        1 to 50 employees     5.0
# 512            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 513        Less than $1 million (USD)                  Unknown     4.7
# 514            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 515          Unknown / Non-Applicable    501 to 1000 employees     3.6
# 516  $500 million to $1 billion (USD)   1001 to 5000 employees     3.9
# 517          Unknown / Non-Applicable      51 to 200 employees     2.7
# 518          Unknown / Non-Applicable     201 to 500 employees     4.8
# 519                                -1                       -1    -1.0
# 520           $5 to $10 million (USD)      51 to 200 employees     4.0
# 521          $10 to $25 million (USD)      51 to 200 employees     3.8
# 522          Unknown / Non-Applicable    501 to 1000 employees     4.2
# 523  $500 million to $1 billion (USD)   1001 to 5000 employees     3.9
# 524          Unknown / Non-Applicable                  Unknown    -1.0
# 525          Unknown / Non-Applicable        1 to 50 employees     4.5
# 526        $100 to $500 million (USD)     201 to 500 employees     3.5
# 527            $1 to $2 billion (USD)   1001 to 5000 employees     2.7
# 528          $25 to $50 million (USD)      51 to 200 employees     3.5
# 529          Unknown / Non-Applicable        1 to 50 employees     4.9
# 530          $25 to $50 million (USD)      51 to 200 employees     3.6
# 531          Unknown / Non-Applicable        1 to 50 employees     5.0
# 532            $1 to $5 million (USD)        1 to 50 employees     3.1
# 533          Unknown / Non-Applicable    501 to 1000 employees     3.9
# 534          $25 to $50 million (USD)      51 to 200 employees     3.4
# 535                $10+ billion (USD)         10000+ employees     4.1
# 536            $1 to $2 billion (USD)         10000+ employees     4.1
# 537          Unknown / Non-Applicable     201 to 500 employees     3.5
# 538        $100 to $500 million (USD)    501 to 1000 employees     4.3
# 539        $100 to $500 million (USD)     201 to 500 employees     4.4
# 540         $50 to $100 million (USD)   1001 to 5000 employees     3.8
# 541          Unknown / Non-Applicable  5001 to 10000 employees     3.7
# 542  $500 million to $1 billion (USD)   1001 to 5000 employees     3.9
# 543          $25 to $50 million (USD)    501 to 1000 employees     3.9
# 544                $10+ billion (USD)  5001 to 10000 employees     3.7
# 545          $25 to $50 million (USD)    501 to 1000 employees     2.9
# 546          Unknown / Non-Applicable      51 to 200 employees     4.6
# 547          $10 to $25 million (USD)     201 to 500 employees     3.4
# 548                $10+ billion (USD)         10000+ employees     4.0
# 549        $100 to $500 million (USD)     201 to 500 employees     3.3
# 550          $25 to $50 million (USD)      51 to 200 employees     4.3
# 551          Unknown / Non-Applicable    501 to 1000 employees     3.9
# 552          Unknown / Non-Applicable   1001 to 5000 employees     3.6
# 553        $100 to $500 million (USD)   1001 to 5000 employees     4.7
# 554                $10+ billion (USD)  5001 to 10000 employees     3.6
# 555                                -1                       -1    -1.0
# 556          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 557  $500 million to $1 billion (USD)    501 to 1000 employees     3.3
# 558          $25 to $50 million (USD)      51 to 200 employees     3.8
# 559          Unknown / Non-Applicable    501 to 1000 employees     4.5
# 560          $25 to $50 million (USD)      51 to 200 employees     4.5
# 561            $1 to $2 billion (USD)   1001 to 5000 employees     3.4
# 562  $500 million to $1 billion (USD)   1001 to 5000 employees     3.1
# 563            $2 to $5 billion (USD)  5001 to 10000 employees     4.0
# 564          Unknown / Non-Applicable    501 to 1000 employees     3.3
# 565        $100 to $500 million (USD)   1001 to 5000 employees     4.1
# 566        $100 to $500 million (USD)      51 to 200 employees     4.2
# 567          Unknown / Non-Applicable        1 to 50 employees     3.9
# 568          Unknown / Non-Applicable                  Unknown    -1.0
# 569            $1 to $2 billion (USD)  5001 to 10000 employees     3.3
# 570                $10+ billion (USD)         10000+ employees     3.9
# 571          $10 to $25 million (USD)      51 to 200 employees     4.5
# 572        $100 to $500 million (USD)    501 to 1000 employees     4.2
# 573            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 574        $100 to $500 million (USD)   1001 to 5000 employees     4.0
# 575        $100 to $500 million (USD)     201 to 500 employees     4.5
# 576        $100 to $500 million (USD)    501 to 1000 employees     4.5
# 577          Unknown / Non-Applicable    501 to 1000 employees     3.8
# 578          Unknown / Non-Applicable         10000+ employees     3.9
# 579          Unknown / Non-Applicable      51 to 200 employees     2.0
# 580          Unknown / Non-Applicable      51 to 200 employees     4.8
# 581          Unknown / Non-Applicable         10000+ employees     3.9
# 582                $10+ billion (USD)  5001 to 10000 employees     3.3
# 583            $1 to $2 billion (USD)  5001 to 10000 employees     3.3
# 584          Unknown / Non-Applicable      51 to 200 employees     5.0
# 585          Unknown / Non-Applicable      51 to 200 employees     4.4
# 586          $10 to $25 million (USD)      51 to 200 employees     3.4
# 587            $1 to $2 billion (USD)   1001 to 5000 employees     3.3
# 588          Unknown / Non-Applicable      51 to 200 employees     2.9
# 589            $2 to $5 billion (USD)         10000+ employees     3.8
# 590            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 591                $10+ billion (USD)         10000+ employees     4.0
# 592            $2 to $5 billion (USD)  5001 to 10000 employees     4.0
# 593        $100 to $500 million (USD)   1001 to 5000 employees     3.4
# 594                $10+ billion (USD)         10000+ employees     3.9
# 595          Unknown / Non-Applicable                  Unknown     3.8
# 596         $50 to $100 million (USD)     201 to 500 employees     4.5
# 597          $10 to $25 million (USD)      51 to 200 employees     4.3
# 598          Unknown / Non-Applicable        1 to 50 employees     3.6
# 599          Unknown / Non-Applicable         10000+ employees     2.9
# 600        $100 to $500 million (USD)     201 to 500 employees     2.9
# 601          $25 to $50 million (USD)      51 to 200 employees     3.2
# 602            $1 to $2 billion (USD)  5001 to 10000 employees     4.5
# 603            $1 to $5 million (USD)        1 to 50 employees     5.0
# 604            $1 to $5 million (USD)        1 to 50 employees     3.5
# 605        Less than $1 million (USD)        1 to 50 employees     4.0
# 606        $100 to $500 million (USD)      51 to 200 employees     4.4
# 607            $1 to $2 billion (USD)         10000+ employees     4.2
# 608            $1 to $5 million (USD)        1 to 50 employees     3.2
# 609          $25 to $50 million (USD)      51 to 200 employees     3.4
# 610            $1 to $5 million (USD)        1 to 50 employees     4.7
# 611          Unknown / Non-Applicable     201 to 500 employees     3.6
# 612            $1 to $2 billion (USD)  5001 to 10000 employees     4.2
# 613                                -1                       -1    -1.0
# 614                $10+ billion (USD)         10000+ employees     3.2
# 615          Unknown / Non-Applicable                  Unknown    -1.0
# 616            $2 to $5 billion (USD)   1001 to 5000 employees     2.8
# 617            $1 to $2 billion (USD)         10000+ employees     4.2
# 618          Unknown / Non-Applicable      51 to 200 employees     4.5
# 619          $10 to $25 million (USD)      51 to 200 employees     3.0
# 620            $1 to $2 billion (USD)  5001 to 10000 employees     3.3
# 621        Less than $1 million (USD)        1 to 50 employees     4.0
# 622          Unknown / Non-Applicable    501 to 1000 employees     3.5
# 623         $50 to $100 million (USD)        1 to 50 employees     3.5
# 624          $10 to $25 million (USD)      51 to 200 employees     3.6
# 625          Unknown / Non-Applicable      51 to 200 employees     3.0
# 626        $100 to $500 million (USD)   1001 to 5000 employees     4.0
# 627          $10 to $25 million (USD)        1 to 50 employees     4.6
# 628        $100 to $500 million (USD)   1001 to 5000 employees     4.3
# 629          $10 to $25 million (USD)      51 to 200 employees     4.7
# 630          Unknown / Non-Applicable     201 to 500 employees     3.7
# 631                $10+ billion (USD)         10000+ employees     3.9
# 632        Less than $1 million (USD)        1 to 50 employees     4.9
# 633           $5 to $10 million (USD)      51 to 200 employees     3.0
# 634          Unknown / Non-Applicable  5001 to 10000 employees     2.5
# 635          $25 to $50 million (USD)      51 to 200 employees     3.5
# 636            $1 to $5 million (USD)        1 to 50 employees     5.0
# 637          Unknown / Non-Applicable        1 to 50 employees    -1.0
# 638            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# 639          Unknown / Non-Applicable      51 to 200 employees     3.0
# 640          Unknown / Non-Applicable        1 to 50 employees     5.0
# 641          Unknown / Non-Applicable      51 to 200 employees     4.7
# 642        $100 to $500 million (USD)     201 to 500 employees     3.3
# 643          Unknown / Non-Applicable   1001 to 5000 employees     3.3
# 644            $2 to $5 billion (USD)         10000+ employees     3.5
# 645                $10+ billion (USD)         10000+ employees     4.1
# 646            $2 to $5 billion (USD)  5001 to 10000 employees     3.5
# ...
# 188                Herndon, VA
# 189                Waltham, MA
# 190               San Jose, CA
# 191          Mountain View, CA
# 192  Cambridge, United Kingdom
# 193            Jersey City, NJ
# 194  Cambridge, United Kingdom
# 195             Santa Cruz, CA
# 196             Fort Worth, TX
# 197              Cambridge, MA
# 198           Cedar Rapids, IA
# 199             Washington, DC
# 200                Chicago, IL
# 201                 McLean, VA
# 202                 Lorton, VA
# 203          San Francisco, CA
# 204         Basel, Switzerland
# 205                Mc Lean, VA
# 206                Mc Lean, VA
# 207            Maple Plain, MN
# 208                   Kent, WA
# 209               Woodbine, MD
# 210                 Denver, CO
# 211            Westminster, CO
# 212               Woodbine, MD
# 213                 Boston, MA
# 214            San Antonio, TX
# 215  Cambridge, United Kingdom
# 216                 Reston, VA
# 217          Scotts Valley, CA
# 218            Springfield, MA
# 219                Chicago, IL
# 220            Spartanburg, SC
# 221               New York, NY
# 222                Orlando, FL
# 593             Saint Paul, MN
# 594  Brentford, United Kingdom
# 595                Langley, VA
# 596                Chicago, IL
# 597            Minneapolis, MN
# 598               New York, NY
# 599              Nashville, TN
# 600                 Reston, VA
# 601            Los Angeles, CA
# 602                 Laurel, MD
# 603               Woodbine, MD
# 604            Aliso Viejo, CA
# 605             Plainsboro, NJ
# 606                 Reston, VA
# 607            Aliso Viejo, CA
# 608                  Plano, TX
# 609                Fairfax, VA
# 610               Fairmont, WV
# 611           South Jordan, UT
# 612                Herndon, VA
# 613                         -1
# 614               Bethesda, MD
# 615                 McLean, VA
# 616            Albertville, AL
# 617            Aliso Viejo, CA
# 618                Fairfax, VA
# 619               Bellevue, WA
# 620              San Diego, CA
# 621       Westlake Village, CA
# 622                 Orange, CA
# 623               New York, NY
# 624              Littleton, CO
# 625             Alexandria, VA
# 626                 Reston, VA
# 627                Houston, TX
# 628           Oakville, Canada
# 629                 Itasca, IL
# 630                 Vienna, VA
# 631                Mc Lean, VA
# 632                Holmdel, NJ
# 633                Fremont, CA
# 634             Naperville, IL
# 635          San Francisco, CA
# 636               Woodbine, MD
# 637                         -1
# 638            Westminster, CO
# 639              San Bruno, CA
# 640          Coconut Creek, FL
# 641             Naperville, IL
# 642            Kansas City, MO
# 643                Houston, TX
# 644              Arlington, VA
# 645              Cupertino, CA
# 646            Westminster, CO
# 647            San Antonio, TX
# 648               Danville, CA
# 649                 Boston, MA
# 650                         -1
# 651  Cambridge, United Kingdom
# 652                 Denver, CO
# 653              Sunnyvale, CA
# 654              Chantilly, VA
# 655               Columbus, OH
# 656                         -1
# 657                         -1
# 658              Arlington, VA
# 659              Chantilly, VA
# 660                         -1
# 661           West Chester, PA
# 662             Wilmington, MA
# 663                  Utica, MI
# 664              Baltimore, MD
# 665                 Vienna, VA
# 666              Cambridge, MA
# 667               Fort Lee, NJ
# 668                         -1
# 669                         -1
# 670            Santa Clara, CA
# 671            Carle Place, NY  >

# %%
df_company.isna().sum()
# Out:
# Revenue         0
# Size            0
# Rating          0
# Headquarters    0
# dtype: int64

# %%
for column in df_company.columns:
    print(f"============= {column} =================")
    display(df_company[column].value_counts())
    print()
# Out:
# ============= Revenue =================
# Revenue
# Unknown / Non-Applicable            213
# $100 to $500 million (USD)           94
# $10+ billion (USD)                   63
# $2 to $5 billion (USD)               45
# $10 to $25 million (USD)             41
# $1 to $2 billion (USD)               36
# $25 to $50 million (USD)             36
# $50 to $100 million (USD)            31
# $1 to $5 million (USD)               31
# -1                                   27
# $500 million to $1 billion (USD)     19
# $5 to $10 million (USD)              14
# Less than $1 million (USD)           14
# $5 to $10 billion (USD)               8
# Name: count, dtype: int64
# ============= Size =================
# Size
# 51 to 200 employees        135
# 1001 to 5000 employees     104
# 1 to 50 employees           86
# 201 to 500 employees        85
# 10000+ employees            80
# 501 to 1000 employees       77
# 5001 to 10000 employees     61
# -1                          27
# Unknown                     17
# Name: count, dtype: int64
# ============= Rating =================
# Rating
#  3.5    58
# -1.0    50
#  3.3    41
#  4.0    41
#  3.9    40
#  3.8    39
#  3.7    38
#  5.0    36
#  4.5    32
#  3.6    31
#  3.4    31
#  4.2    29
#  4.1    25
#  4.4    24
#  4.7    22
#  3.2    21
#  4.8    20
#  2.9    14
#  4.3    14
#  3.1    12
#  4.6    12
#  4.9    11
#  2.7    10
#  3.0     7
#  2.6     4
#  2.8     3
#  2.5     2
#  2.2     1
#  2.4     1
#  2.3     1
#  2.1     1
#  2.0     1
# Name: count, dtype: int64
# ============= Headquarters =================
# Headquarters
# New York, NY                 33
# San Francisco, CA            31
# -1                           31
# Chicago, IL                  23
# Boston, MA                   19
# Reston, VA                   14
# Mc Lean, VA                  13
# Westminster, CO              12
# Cambridge, MA                10
# Cambridge, United Kingdom    10
# Vienna, VA                    8
# Herndon, VA                   7
# Bedford, MA                   7
# Saint Louis, MO               7
# Washington, DC                7
# Denver, CO                    7
# Arlington, VA                 7
# San Jose, CA                  7
# Woodbine, MD                  7
# Basel, Switzerland            6
# Mountain View, CA             6
# Chantilly, VA                 6
# San Rafael, CA                6
# San Antonio, TX               6
# Princeton, NJ                 5
# Bellevue, WA                  5
# Rockville, MD                 5
# Bethesda, MD                  5
# Fairfax, VA                   5
# Springfield, MA               5
# Houston, TX                   5
# Pittsburgh, PA                5
# Los Angeles, CA               5
# Memphis, TN                   4
# Orlando, FL                   4
# Falls Church, VA              4
# South San Francisco, CA       4
# Palo Alto, CA                 4
# Santa Clara, CA               4
# Austin, TX                    4
# Santa Cruz, CA                4
# Annapolis Junction, MD        4
# San Diego, CA                 4
# Cedar Rapids, IA              4
# McLean, VA                    4
# Pleasanton, CA                4
# Raleigh, NC                   4
# Aliso Viejo, CA               4
# Richland, WA                  3
# Atlanta, GA                   3
# Seattle, WA                   3
# Lincoln, NE                   3
# Woburn, MA                    3
# Carson, CA                    3
# Winter Park, FL               3
# Hartford, CT                  3
# Minneapolis, MN               3
# Indianapolis, IN              3
# Sunnyvale, CA                 3
# Jersey City, NJ               3
# Maple Plain, MN               3
# Paris, France                 3
# Columbus, OH                  3
# Hillsborough, NJ              3
# Naperville, IL                3
# Westlake Village, CA          3
# Laurel, MD                    3
# Folsom, CA                    3
# Alexandria, VA                3
# Santa Barbara, CA             2
# Northbrook, IL                2
# Mays Landing, NJ              2
# Menlo Park, CA                2
# Lexington, MA                 2
# Sheboygan, WI                 2
# Santa Monica, CA              2
# Singapore, Singapore          2
# OSAKA, Japan                  2
# San Ramon, CA                 2
# Chevy Chase, MD               2
# Emeryville, CA                2
# South Jordan, UT              2
# Holmdel, NJ                   2
# San Mateo, CA                 2
# Lehi, UT                      2
# Stamford, CT                  2
# Greenville, SC                2
# Hamilton, Bermuda             2
# Lynchburg, VA                 2
# San Carlos, CA                2
# Waltham, MA                   2
# Fort Worth, TX                2
# Lorton, VA                    2
# Kent, WA                      2
# Scotts Valley, CA             2
# Baltimore, MD                 2
# Toronto, Canada               2
# Irvine, CA                    2
# Fremont, CA                   2
# Brentford, United Kingdom     2
# Cincinnati, OH                2
# Somerset, NJ                  2
# London, United Kingdom        2
# Leesburg, VA                  2
# Kent, OH                      2
# North Brunswick, NJ           2
# Name: count, dtype: int64

# %% [markdown]
# ### Aturan missing value handling :
# 1. jika tipe datanya itu **numerik** -> handling menggunakan **median** (robust / tahan terhadap outlier)
# 2. jika tipe datanya itu **kategorik / object / string** -> handling menggunakan **mode / modus**

# %%
from sklearn.model_selection import train_test_split
#Splitting terlebih dahulu

#train : test = 80:20 atau 75:25 atau (minimum :70:30 atau maksimum: 90:10) bagi angka yg lain (85:15)

# %% [markdown]
# ## Assignment 2. Missing Value Handling :
# 1. Cek persentase missing value pada kolom Headquarters di company.csv, Cek jenis missing valuenya ?
# 2. apakah di drop atau tidak (gunakan syarat drop kolom jika > 20%)
# 3. jika tidak maka handling, dan dengan cara apa handling nilainya, median atau modus ?

# %%
#Tulis jawaban missing value handling kolom Headquarters disini
df_company = pd.read_csv('company.csv')

# %%
df_company.head()
# Out:
#                       Revenue                     Size  Rating  \
# 0    Unknown / Non-Applicable   1001 to 5000 employees     3.1
# 1      $1 to $2 billion (USD)  5001 to 10000 employees     4.2
# 2  $100 to $500 million (USD)   1001 to 5000 employees     3.8
# 3  $100 to $500 million (USD)    501 to 1000 employees     3.5
# 4    Unknown / Non-Applicable      51 to 200 employees     2.9
#
#              Headquarters
# 0            New York, NY
# 1             Herndon, VA
# 2              Boston, MA
# 3  Bad Ragaz, Switzerland
# 4            New York, NY

# %%
df_company.isna().sum()
# Out:
# Revenue         0
# Size            0
# Rating          0
# Headquarters    0
# dtype: int64

# %%
for column in df_company.columns:
    print(f"============= {column} =================")
    display(df_company[column].value_counts())
    print()
# Out:
# ============= Revenue =================
# Revenue
# Unknown / Non-Applicable            213
# $100 to $500 million (USD)           94
# $10+ billion (USD)                   63
# $2 to $5 billion (USD)               45
# $10 to $25 million (USD)             41
# $1 to $2 billion (USD)               36
# $25 to $50 million (USD)             36
# $50 to $100 million (USD)            31
# $1 to $5 million (USD)               31
# -1                                   27
# $500 million to $1 billion (USD)     19
# $5 to $10 million (USD)              14
# Less than $1 million (USD)           14
# $5 to $10 billion (USD)               8
# Name: count, dtype: int64
# ============= Size =================
# Size
# 51 to 200 employees        135
# 1001 to 5000 employees     104
# 1 to 50 employees           86
# 201 to 500 employees        85
# 10000+ employees            80
# 501 to 1000 employees       77
# 5001 to 10000 employees     61
# -1                          27
# Unknown                     17
# Name: count, dtype: int64
# ============= Rating =================
# Rating
#  3.5    58
# -1.0    50
#  3.3    41
#  4.0    41
#  3.9    40
#  3.8    39
#  3.7    38
#  5.0    36
#  4.5    32
#  3.6    31
#  3.4    31
#  4.2    29
#  4.1    25
#  4.4    24
#  4.7    22
#  3.2    21
#  4.8    20
#  2.9    14
#  4.3    14
#  3.1    12
#  4.6    12
#  4.9    11
#  2.7    10
#  3.0     7
#  2.6     4
#  2.8     3
#  2.5     2
#  2.2     1
#  2.4     1
#  2.3     1
#  2.1     1
#  2.0     1
# Name: count, dtype: int64
# ============= Headquarters =================
# Headquarters
# New York, NY                 33
# San Francisco, CA            31
# -1                           31
# Chicago, IL                  23
# Boston, MA                   19
# Reston, VA                   14
# Mc Lean, VA                  13
# Westminster, CO              12
# Brisbane, CA                  1
# Deerfield, IL                 1
# Ipswich, MA                   1
# Carmel, IN                    1
# Yakima, WA                    1
# Aurora, CO                    1
# Goleta, CA                    1
# Franklin, TN                  1
# Lutherville Timonium, MD      1
# Burlingame, CA                1
# Beavercreek, OH               1
# Schaumburg, IL                1
# Lake Oswego, OR               1
# Holyoke, MA                   1
# Dulles, VA                    1
# Detroit, MI                   1
# Carpinteria, CA               1
# Columbia, SC                  1
# Marcy-l'Etoile, France        1
# Columbia, MO                  1
# Chandler, AZ                  1
# Aurora, Canada                1
# Blue Bell, PA                 1
# Troy, MI                      1
# Redwood City, CA              1
# Harrisburg, PA                1
# Spartanburg, SC               1
# Woodbridge, NJ                1
# Chennai, India                1
# Tel Aviv-Yafo, Israel         1
# Manalapan, NJ                 1
# Charlotte, NC                 1
# Saxonburg, PA                 1
# Bristol, PA                   1
# Bangalore, India              1
# Hoboken, NJ                   1
# Greenwich, CT                 1
# Santa Ana, CA                 1
# Tucson, AZ                    1
# Birmingham, AL                1
# Cleveland, OH                 1
# Piscataway, NJ                1
# Danvers, MA                   1
# Philadelphia, PA              1
# Livermore, CA                 1
# Dallas, TX                    1
# Oshkosh, WI                   1
# Monroe, WI                    1
# Goteborg, Sweden              1
# Lake Buena Vista, FL          1
# Schaffhausen, Switzerland     1
# Richmond, VA                  1
# Newark, CA                    1
# Greensboro, NC                1
# Scottsdale, AZ                1
# Irving, TX                    1
# Beltsville, MD                1
# Durham, NC                    1
# Benicia, CA                   1
# Reading, MA                   1
# Wilsonville, OR               1
# Madison, WI                   1
# Phila, PA                     1
# Half Moon Bay, CA             1
# Hilliard, OH                  1
# Hanover, MD                   1
# Bengaluru, India              1
# Alpharetta, GA                1
# Omaha, NE                     1
# Clifton Park, NY              1
# Livonia, MI                   1
# Ashburn, VA                   1
# Ventura, CA                   1
# Armonk, NY                    1
# Trumbull, CT                  1
# Chadds Ford, PA               1
# Glen Allen, VA                1
# Cherry Hill, NJ               1
# Lombard, IL                   1
# Honolulu, HI                  1
# Tampa, FL                     1
# Totowa, NJ                    1
# Rome, NY                      1
# Milan, IL                     1
# Marbella, Spain               1
# Simi Valley, CA               1
# Rancho Cucamonga, CA          1
# Albuquerque, NM               1
# Langley, VA                   1
# Plano, TX                     1
# Albertville, AL               1
# Orange, CA                    1
# Littleton, CO                 1
# Oakville, Canada              1
# San Bruno, CA                 1
# West Chester, PA              1
# Utica, MI                     1
# Fort Lee, NJ                  1
# Name: count, dtype: int64

# %%
train_company['Headquarters'] = train_company['Headquarters'].replace(
    ['-1', 'Unknown / Non-Applicable'], np.nan
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Headquarters'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 train_company['Headquarters'] = train_company['Headquarters'].replace(
#       2     ['-1', 'Unknown / Non-Applicable'], np.nan
#       3 )
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Headquarters'

# %%
df_company = df_company.drop(columns=['Headquarters'])
df_company.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df_company = df_company.drop(columns=['Headquarters'])
#       2 df_company.info()
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4642 for axis, labels in axes.items():
#    4643     if labels is not None:
# -> 4644         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4646 if inplace:
#    4647     self._update_inplace(obj)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4684         new_axis = axis.drop(labels, level=level, errors=errors)
#    4685     else:
# -> 4686         new_axis = axis.drop(labels, errors=errors)
#    4687     indexer = axis.get_indexer(new_axis)
#    4689 # Case for non-unique axis
#    4690 else:
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['Headquarters'] not found in axis"

# %%
from sklearn.model_selection import train_test_split
train_company, test_company = train_test_split(df_company, test_size = 0.2, random_state=42)

# %% [markdown]
# # D. Encoding
# Definisi : Mengubah tipe kategorikal menjadi numerikal dengan pendekatan aturan encoding untuk persiapan sebelum dilakukannya machine learning modelling. Teknik Encoding yang umum dipakai :
# 1. One Hot Encoding (OHE) : Lakukan pada kolom gender
# 2. Label Encoding / Ordinal Encoding : Lakukan pada kolom Yes dan No, Jika Yes menjadi 1 , Jika No menjadi 0. Sebagai Contohnya di kolom  Partner, Dependents.
# 3. Mean Encoding : Contract

# %%
df_churn = pd.read_csv('Telco-Customer-Churn.csv')

# %%
#Splitting terlebih dahulu

# %% [markdown]
# ## Assignment 3.a Label Encoder :
# 1. Pilih kolom-kolom StreamingMovies, StreamingTV, TechSupport, DeviceProtection, OnlineBackup, OnlineSecurity, MultipleLines
# 2. Ganti nilai yang tidak sesuai : No internet service menjadi No lalu validasi dengan value_counts
# 3. Kemudian lakukan label Encoder
# 4. Notes : gunakan Telco-Customer-Churn.csv

# %%
#Tulis jawaban
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Selesai :)
